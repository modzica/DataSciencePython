# %%
a = 10
b = 3.5
c = "Python"
d = True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(a + b)
# Out:
# 13.5

# %%
print(a / b)
# Out:
# 2.857142857142857

# %%
print(a * a)
# Out:
# 100

# %%
print(a - a * b)
# Out:
# -25.0

# %%
print(a ** 3)
# Out:
# 1000

# %%
print(f"Wartość a to {a}, a b to {b}, string c opisuje {c}, a wartosc d jest {d}.")
# Out:
# Wartość a to 10, a b to 3.5, string c opisuje Python, a wartosc d jest True.
