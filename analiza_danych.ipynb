# %%
import numpy as np 
import pandas as pd 

data = { 
    "Imię": ["Ala", "Bartek", "Celina"], 
    "Wiek": [22, 25, 20], 
    "Ocena": [4.5, 3.8, 5.0],
    "Rok studiów": [2, 3, 4]
} 
df = pd.DataFrame(data) 
display(df) 
print(df.describe())
# Out:
#      Imię  Wiek  Ocena  Rok studiów
# 0     Ala    22    4.5            2
# 1  Bartek    25    3.8            3
# 2  Celina    20    5.0            4
#             Wiek     Ocena  Rok studiów
# count   3.000000  3.000000          3.0
# mean   22.333333  4.433333          3.0
# std     2.516611  0.602771          1.0
# min    20.000000  3.800000          2.0
# 25%    21.000000  4.150000          2.5
# 50%    22.000000  4.500000          3.0
# 75%    23.500000  4.750000          3.5
# max    25.000000  5.000000          4.0

# %%
    srednia_kolumna1 = df['Ocena'].mean()
    print(f"Średnia Ocen: {srednia_kolumna1}")
# Out:
# Średnia Ocen: 4.433333333333334

# %%
oceny_wiekszeod4 = df[df['Ocena'] > 4]

print(oceny_wiekszeod4)
# Out:
#      Imię  Wiek  Ocena  Rok studiów
# 0     Ala    22    4.5            2
# 2  Celina    20    5.0            4
