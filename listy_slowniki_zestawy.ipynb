# %%
fruits = ["jabłko", "banan", "malina", "truskawka"] 
person = {"name": "Ala", "age": 22} 
numbers = {1, 2, 3, 3}

# %%
print(fruits[1])
# Out:
# banan

# %%
lista = (4,8,15,16,23,42)

# %%
srednia = sum(lista) / len(lista)
print(srednia)
# Out:
# 18.0

# %%
for key, value in person.items():
    print(key, ":", value)
# Out:
# name : Ala
# age : 22
